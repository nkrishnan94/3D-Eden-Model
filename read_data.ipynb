# %%
import os,glob
import numpy as np
import matplotlib.pyplot as plt

# %%
files =glob.glob("3D_eden_cpp/prof_T*.txt")
sz=50

# %%
files
# Out:
# ['3D_eden_cpp/prof_T0_2020-09-16-17-26-42.txt',
#  '3D_eden_cpp/prof_T10_2020-09-16-17-26-42.txt',
#  '3D_eden_cpp/prof_T5_2020-09-16-17-26-42.txt',
#  '3D_eden_cpp/prof_T15_2020-09-16-17-26-42.txt']

# %%
arr =np.loadtxt(files[-2],delimiter=", ")
arr=arr[:,3].reshape(100,100,100)

# %%
plt.imshow(arr[:,:,0])

# %%
plt.imshow(arr[:,:,5])

# %%
plt.imshow(np.argmin(arr,axis=2))
plt.colorbar()

# %%
plt.imshow(np.argmax(arr,axis=2))
plt.colorbar()

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].

    
for m in np.argwhere(arr==1):
    ax.scatter(*m,c='k',s=10)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.set_xlim([0,100])
ax.set_ylim([0,100])
ax.set_zlim([0,100])
plt.show()
